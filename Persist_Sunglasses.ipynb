# %%
import json, os, requests

from key import API_KEY

API_KEY = API_KEY # Enter your API Key/"App ID" Here. Mine was 40 chars long.

# FILM_CAMS = '15230'
# ELEC_GUITARS = '33034' # Category code for electric guitars on eBay.
# WATCHES = '14324'
MENS_SUNGLASSES = '79720'

# %%
USA = 'EBAY-US' # USA Marketplace only. API seems to start returning stuff from other markets eventually anyhow
USED = '3000' # Just the code for item condition "used". This is the focus of this project.
AUCTIONWITHBIN = "AuctionWithBIN"
AUCTION = "Auction"

ITEM_FILTER_0 = f'itemFilter(0).name=Condition&itemFilter(0).value={USED}' # Only used guitars
ITEM_FILTER_1 = f'itemFilter(1).name=HideDuplicateItems&itemFilter(1).value=true' # No duplicate listings
ITEM_FILTER_2 = f'itemFilter(2).name=MinPrice&itemFilter(2).value=49' # Only items that sold for > this value
ITEM_FILTER_3 = f'itemFilter(3).name=MaxQuantity&itemFilter(3).value=1' # No lots or batch sales. One item at a time
ITEM_FILTER_4 = f'itemFilter(4).name=SoldItemsOnly&itemFilter(4).value=true' # Only looking at listings that sold.
ITEM_FILTER_5 = f'itemFilter(5).name=ListingType&itemFilter(5).value={AUCTION}' # Select sale type.
ITEM_FILTER_6 = f'itemFilter(6).name=MaxPrice&itemFilter(6).value=2000' # Only items that sold for < this value
ITEM_FILTER_7 = f'itemFilter(7).name=listingType&itemFilter(7).value={AUCTIONWITHBIN}' # Select sale type.

FIND_COMPLETED = 'findCompletedItems' # This is the eBay API endpoint service we'll be querying.

# %%
def find_completed_auction(PAGE):
    '''Make a request to the eBay API and return the JSON text of this page number'''
    r = requests.get(f'https://svcs.ebay.com/services/search/FindingService/v1?'
                 f'OPERATION-NAME={FIND_COMPLETED}&'
                 f'X-EBAY-SOA-SECURITY-APPNAME={API_KEY}&'
                 f'RESPONSE-DATA-FORMAT=JSON&' # This value can be altered if you're not into JSON responses
                 f'REST-PAYLOAD&'
                 f'GLOBAL-ID={USA}&' # seems to prioritize the value you enter but returns other stuff too
                 f'categoryId={MENS_SUNGLASSES}&' # Product category goes here
                 f'descriptionSearch=true&' # More verbose responses
                 f'{ITEM_FILTER_0}&' # USED
                 f'{ITEM_FILTER_1}&' # NO DUPES
                 f'{ITEM_FILTER_2}&' # MINPRICE
                 f'{ITEM_FILTER_3}&' # NO LOTS
                 f'{ITEM_FILTER_4}&' # ONLY SOLD
                 f'{ITEM_FILTER_5}&' # AUCTIONS ONLY
                 f'{ITEM_FILTER_6}&' # MAX PRICE
                 f'paginationInput.pageNumber={str(PAGE)}&' # value to be looped through when collecting lotsa data
                 f'outputSelector=PictureURLLarge') # Why not grab the thumbnail URLs too. Could be cool
    if r.json()['findCompletedItemsResponse'][0].get('searchResult'):
        return r.json()['findCompletedItemsResponse'][0]['searchResult'][0]['item']
    else:
        return None

# %%
find_completed_auction(1)
# Out:
# [{'itemId': ['123702795250'],
#   'title': ['Used Oakley Sunglasses LIMITED EDITION Bronze Decay/Warm Grey OO9102-57'],
#   'globalId': ['EBAY-US'],
#   'primaryCategory': [{'categoryId': ['79720'],
#     'categoryName': ['Sunglasses']}],
#   'galleryURL': ['http://thumbs3.ebaystatic.com/m/mT9KDbIpZtDUXTOsl0jSpSQ/140.jpg'],
#   'viewItemURL': ['http://www.ebay.com/itm/Used-Oakley-Sunglasses-LIMITED-EDITION-Bronze-Decay-Warm-Grey-OO9102-57-/123702795250'],
#   'paymentMethod': ['PayPal'],
#   'autoPay': ['false'],
#   'postalCode': ['34482'],
#   'location': ['Ocala,FL,USA'],
#   'country': ['US'],
#   'shippingInfo': [{'shippingServiceCost': [{'@currencyId': 'USD',
#       '__value__': '0.0'}],
#     'shippingType': ['Free'],
#     'shipToLocations': ['Worldwide'],
#     'expeditedShipping': ['true'],
#     'oneDayShippingAvailable': ['false'],
#     'handlingTime': ['2']}],
#   'sellingStatus': [{'currentPrice': [{'@currencyId': 'USD',
#       '__value__': '49.99'}],
#     'convertedCurrentPrice': [{'@currencyId': 'USD', '__value__': '49.99'}],
#     'bidCount': ['1'],
#     'sellingState': ['EndedWithSales']}],
#   'listingInfo': [{'bestOfferEnabled': ['false'],
#     'buyItNowAvailable': ['false'],
#     'startTime': ['2019-03-22T13:52:10.000Z'],
#     'endTime': ['2019-03-29T13:52:10.000Z'],
#     'listingType': ['Auction'],
#     'gift': ['false']}],
#   'returnsAccepted': ['true'],
#   'condition': [{'conditionId': ['3000'],
#     'conditionDisplayName': ['Pre-owned']}],
#   'isMultiVariationListing': ['false'],
#   'pictureURLLarge': ['https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z/WyEAAOSw3b9ck8Hr/$_1.JPG'],
#   'topRatedListing': ['false']},
#  {'itemId': ['173852147482'],
#   'title': ['ALL ORIGINAL - Oakley Men X-Metal Juliet Titanium with Iridium Blue Lenses'],
#   'globalId': ['EBAY-US'],
#   'primaryCategory': [{'categoryId': ['79720'],
#     'categoryName': ['Sunglasses']}],
#   'galleryURL': ['http://thumbs3.ebaystatic.com/m/myjP7UwIpiqPTxuscJju9ZA/140.jpg'],
#   'viewItemURL': ['http://www.ebay.com/itm/ALL-ORIGINAL-Oakley-Men-X-Metal-Juliet-Titanium-Iridium-Blue-Lenses-/173852147482'],
#   'paymentMethod': ['PayPal'],
#   'autoPay': ['false'],
#   'postalCode': ['02143'],
#   'location': ['Somerville,MA,USA'],
#   'country': ['US'],
#   'shippingInfo': [{'shippingServiceCost': [{'@currencyId': 'USD',
#       '__value__': '0.0'}],
#     'shippingType': ['Free'],
#     'shipToLocations': ['Worldwide'],
#     'expeditedShipping': ['true'],
#     'oneDayShippingAvailable': ['false'],
#     'handlingTime': ['1']}],
#   'sellingStatus': [{'currentPrice': [{'@currencyId': 'USD',
#       '__value__': '255.0'}],
#     'convertedCurrentPrice': [{'@currencyId': 'USD', '__value__': '255.0'}],
#     'bidCount': ['1'],
#     'sellingState': ['EndedWithSales']}],
#   'listingInfo': [{'bestOfferEnabled': ['false'],
#     'buyItNowAvailable': ['false'],
#     'startTime': ['2019-03-27T00:33:01.000Z'],
#     'endTime': ['2019-03-29T12:59:59.000Z'],
#     'listingType': ['Auction'],
#     'gift': ['false'],
#     'watchCount': ['3']}],
#   'returnsAccepted': ['false'],
#   'condition': [{'conditionId': ['3000'],
#     'conditionDisplayName': ['Pre-owned']}],
#   'isMultiVariationListing': ['false'],
#   'pictureURLLarge': ['https://i.ebayimg.com/00/s/NjAxWDE2MDA=/z/3dUAAOSwXF5cErQn/$_1.JPG'],
#   'topRatedListing': ['false']},
#  {'itemId': ['123702780157'],
#   'title': ['Oakley Sunglasses Gascan Black Polarized 12-856 60-15 128'],
#   'globalId': ['EBAY-US'],
#   'primaryCategory': [{'categoryId': ['79720'],
#     'categoryName': ['Sunglasses']}],
#   'galleryURL': ['http://thumbs2.ebaystatic.com/m/mFdICsibSaNyw32PUYsJu6w/140.jpg'],
#   'viewItemURL': ['http://www.ebay.com/itm/Oakley-Sunglasses-Gascan-Black-Polarized-12-856-60-15-128-/123702780157'],
#   'paymentMethod': ['PayPal'],
#   'autoPay': ['false'],
#   'postalCode': ['34482'],
#   'location': ['Ocala,FL,USA'],
#   'country': ['US'],
#   'shippingInfo': [{'shippingServiceCost': [{'@currencyId': 'USD',
#       '__value__': '0.0'}],
#     'shippingType': ['Free'],
#     'shipToLocations': ['Worldwide'],
#     'expeditedShipping': ['true'],
#     'oneDayShippingAvailable': ['false'],
#     'handlingTime': ['2']}],
#   'sellingStatus': [{'currentPrice': [{'@currencyId': 'USD',
#       '__value__': '65.0'}],
#     'convertedCurrentPrice': [{'@currencyId': 'USD', '__value__': '65.0'}],
#     'bidCount': ['1'],
#     'sellingState': ['EndedWithSales']}],
#   'listingInfo': [{'bestOfferEnabled': ['false'],
#     'buyItNowAvailable': ['false'],
#     'startTime': ['2019-03-22T13:33:53.000Z'],
#     'endTime': ['2019-03-29T12:46:55.000Z'],
#     'listingType': ['Auction'],
#     'gift': ['false'],
#     'watchCount': ['2']}],
#   'returnsAccepted': ['true'],
#   'condition': [{'conditionId': ['3000'],
#     'conditionDisplayName': ['Pre-owned']}],
#   'isMultiVariationListing': ['false'],
#   'pictureURLLarge': ['https://i.ebayimg.com/00/s/MTIwMFgxNjAw/z
USA'],
#   'country': ['US'],
#   'shippingInfo': [{'shippingType': ['Calculated'],
#     'shipToLocations': ['Worldwide'],
#     'expeditedShipping': ['false'],
#     'oneDayShippingAvailable': ['false'],
#     'handlingTime': ['2']}],
#   'sellingStatus': [{'currentPrice': [{'@currencyId': 'USD',
#       '__value__': '58.0'}],
#     'convertedCurrentPrice': [{'@currencyId': 'USD', '__value__': '58.0'}],
#     'bidCount': ['7'],
#     'sellingState': ['EndedWithSales']}],
#   'listingInfo': [{'bestOfferEnabled': ['false'],
#     'buyItNowAvailable': ['false'],
#     'startTime': ['2019-03-21T02:02:08.000Z'],
#     'endTime': ['2019-03-28T02:02:08.000Z'],
#     'listingType': ['Auction'],
#     'gift': ['false'],
#     'watchCount': ['25']}],
#   'returnsAccepted': ['true'],
#   'condition': [{'conditionId': ['3000'],
#     'conditionDisplayName': ['Pre-owned']}],
#   'isMultiVariationListing': ['false'],
#   'pictureURLLarge': ['https://i.ebayimg.com/00/s/MTE5N1gxNjAw/z/z48AAOSwI7Jcku~Y/$_1.JPG'],
#   'topRatedListing': ['false']},
#  {'itemId': ['362593368605'],
#   'title': ['Dolce & Gabbana Various Sunglasses Lot (18) Pairs Authentic Used '],
#   'globalId': ['EBAY-US'],
#   'primaryCategory': [{'categoryId': ['79720'],
#     'categoryName': ['Sunglasses']}],
#   'galleryURL': ['http://thumbs2.ebaystatic.com/m/mTwdthz4AhkAJFJR8fUy6cA/140.jpg'],
#   'viewItemURL': ['http://www.ebay.com/itm/Dolce-Gabbana-Various-Sunglasses-Lot-18-Pairs-Authentic-Used-/362593368605'],
#   'paymentMethod': ['PayPal'],
#   'autoPay': ['false'],
#   'postalCode': ['30345'],
#   'location': ['Atlanta,GA,USA'],
#   'country': ['US'],
#   'shippingInfo': [{'shippingServiceCost': [{'@currencyId': 'USD',
#       '__value__': '9.99'}],
#     'shippingType': ['Flat'],
#     'shipToLocations': ['Worldwide'],
#     'expeditedShipping': ['true'],
#     'oneDayShippingAvailable': ['false'],
#     'handlingTime': ['1']}],
#   'sellingStatus': [{'currentPrice': [{'@currencyId': 'USD',
#       '__value__': '133.5'}],
#     'convertedCurrentPrice': [{'@currencyId': 'USD', '__value__': '133.5'}],
#     'bidCount': ['29'],
#     'sellingState': ['EndedWithSales']}],
#   'listingInfo': [{'bestOfferEnabled': ['false'],
#     'buyItNowAvailable': ['false'],
#     'startTime': ['2019-03-23T02:00:37.000Z'],
#     'endTime': ['2019-03-28T02:00:37.000Z'],
#     'listingType': ['Auction'],
#     'gift': ['false'],
#     'watchCount': ['10']}],
#   'returnsAccepted': ['false'],
#   'condition': [{'conditionId': ['3000'],
#     'conditionDisplayName': ['Pre-owned']}],
#   'isMultiVariationListing': ['false'],
#   'pictureURLLarge': ['https://i.ebayimg.com/00/s/MTI0M1gxMTg2/z/TbQAAOSw-r9clOOd/$_1.JPG'],
#   'topRatedListing': ['false']},
#  {'itemId': ['183741090784'],
#   'title': ['Oakley Radar Sunglasses White Frame Cycling Glasses'],
#   'globalId': ['EBAY-US'],
#   'primaryCategory': [{'categoryId': ['79720'],
#     'categoryName': ['Sunglasses']}],
#   'galleryURL': ['http://thumbs1.ebaystatic.com/m/mCFKk_NBAV8h6cL8HXTddbg/140.jpg'],
#   'viewItemURL': ['http://www.ebay.com/itm/Oakley-Radar-Sunglasses-White-Frame-Cycling-Glasses-/183741090784'],
#   'paymentMethod': ['PayPal'],
#   'autoPay': ['false'],
#   'postalCode': ['86326'],
#   'location': ['Cottonwood,AZ,USA'],
#   'country': ['US'],
#   'shippingInfo': [{'shippingType': ['Calculated'],
#     'shipToLocations': ['Worldwide'],
#     'expeditedShipping': ['false'],
#     'oneDayShippingAvailable': ['false'],
#     'handlingTime': ['3']}],
#   'sellingStatus': [{'currentPrice': [{'@currencyId': 'USD',
#       '__value__': '63.0'}],
#     'convertedCurrentPrice': [{'@currencyId': 'USD', '__value__': '63.0'}],
#     'bidCount': ['27'],
#     'sellingState': ['EndedWithSales']}],
#   'listingInfo': [{'bestOfferEnabled': ['false'],
#     'buyItNowAvailable': ['false'],
#     'startTime': ['2019-03-21T01:15:29.000Z'],
#     'endTime': ['2019-03-28T01:14:29.000Z'],
#     'listingType': ['Auction'],
#     'gift': ['false'],
#     'watchCount': ['24']}],
#   'returnsAccepted': ['false'],
#   'condition': [{'conditionId': ['3000'],
#     'conditionDisplayName': ['Pre-owned']}],
#   'isMultiVariationListing': ['false'],
#   'pictureURLLarge': ['https://i.ebayimg.com/00/s/MTE5NVgxNTk5/z/SpcAAOSwTIlckuSb/$_1.JPG'],
#   'topRatedListing': ['false']},
#  {'itemId': ['333125296480'],
#   'title': ['Oliver Peoples Tycoon Sunglasses Black & Crystal - Size 51 - Rare & Hard To Find'],
#   'globalId': ['EBAY-US'],
#   'primaryCategory': [{'categoryId': ['79720'],
#     'categoryName': ['Sunglasses']}],
#   'galleryURL': ['http://thumbs1.ebaystatic.com/m/mPJRUA2Fk8djrKYJNPTeG3w/140.jpg'],
#   'viewItemURL': ['http://www.ebay.com/itm/Oliver-Peoples-Tycoon-Sunglasses-Black-Crystal-Size-51-Rare-Hard-Find-/333125296480'],
#   'paymentMethod': ['PayPal'],
#   'autoPay': ['false'],
#   'postalCode': ['28031'],
#   'location': ['Cornelius,NC,USA'],
#   'country': ['US'],
#   'shippingInfo': [{'shippingServiceCost': [{'@currencyId': 'USD',
#       '__value__': '10.0'}],
#     'shippingType': ['Flat'],
#     'shipToLocations': ['Worldwide'],
#     'expeditedShipping': ['true'],
#     'oneDayShippingAvailable': ['false'],
#     'handlingTime': ['1']}],
#   'sellingStatus': [{'currentPrice': [{'@currencyId': 'USD',
#       '__value__': '50.0'}],
#     'convertedCurrentPrice': [{'@currencyId': 'USD', '__value__': '50.0'}],
#     'bidCount': ['1'],
#     'sellingState': ['EndedWithSales']}],
#   'listingInfo': [{'bestOfferEnabled': ['false'],
#     'buyItNowAvailable': ['false'],
#     'startTime': ['2019-03-21T13:13:40.000Z'],
#     'endTime': ['2019-03-28T01:13:40.000Z'],
#     'listingType': ['Auction'],
#     'gift': ['false'],
#     'watchCount': ['1']}],
#   'returnsAccepted': ['true'],
#   'condition': [{'conditionId': ['3000'],
#     'conditionDisplayName': ['Pre-owned']}],
#   'isMultiVariationListing': ['false'],
#   'pictureURLLarge': ['https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/9H0AAOSw6PtcbfVO/$_1.JPG'],
#   'topRatedListing': ['false']},
#  {'itemId': ['352624495492'],
#   'title': ["Authentic Cartier Men's Sunglasses Genuine Horn 140 Made In France"],
#   'globalId': ['EBAY-US'],
#   'primaryCategory': [{'categoryId': ['79720'],
#     'categoryName': ['Sunglasses']}],
#   'galleryURL': ['http://thumbs1.ebaystatic.com/m/mfeVrJSpksvoCWMwggm90xQ/140.jpg'],
#   'viewItemURL': ['http://www.ebay.com/itm/Authentic-Cartier-Mens-Sunglasses-Genuine-Horn-140-Made-France-/352624495492'],
#   'paymentMethod': ['PayPal'],
#   'autoPay': ['false'],
#   'postalCode': ['49506'],
#   'location': ['Grand Rapids,MI,USA'],
#   'country': ['US'],
#   'shippingInfo': [{'shippingServiceCost': [{'@currencyId': 'USD',
#       '__value__': '0.0'}],
#     'shippingType': ['Free'],
#     'shipToLocations': ['Worldwide'],
#     'expeditedShipping': ['false'],
#     'oneDayShippingAvailable': ['false'],
#     'handlingTime': ['3']}],
#   'sellingStatus': [{'currentPrice': [{'@currencyId': 'USD',
#       '__value__': '300.0'}],
#     'convertedCurrentPrice': [{'@currencyId': 'USD', '__value__': '300.0'}],
#     'bidCount': ['1'],
#     'sellingState': ['EndedWithSales']}],
#   'listingInfo': [{'bestOfferEnabled': ['false'],
#     'buyItNowAvailable': ['false'],
#     'startTime': ['2019-03-23T00:35:36.000Z'],
#     'endTime': ['2019-03-28T00:35:36.000Z'],
#     'listingType': ['Auction'],
#     'gift': ['false'],
#     'watchCount': ['3']}],
#   'returnsAccepted': ['false'],
#   'condition': [{'conditionId': ['3000'],
#     'conditionDisplayName': ['Pre-owned']}],
#   'isMultiVariationListing': ['false'],
#   'pictureURLLarge': ['https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/3EQAAOSwXdlclXnn/$_1.JPG'],
#   'topRatedListing': ['false']},
#  {'itemId': ['132996040446'],
#   'title': ['Maui Jim Peahi polaraized sunglasses- HCL Bronze lens- Like new condition.\xa0'],
#   'globalId': ['EBAY-US'],
#   'primaryCategory': [{'categoryId': ['79720'],
#     'categoryName': ['Sunglasses']}],
#   'galleryURL': ['http://thumbs3.ebaystatic.com/m/mYUCHCh4o1Sx5zteaUFyzJg/140.jpg'],
#   'viewItemURL': ['http://www.ebay.com/itm/Maui-Jim-Peahi-polaraized-sunglasses-HCL-Bronze-lens-Like-new-condition-/132996040446'],
#   'paymentMethod': ['PayPal'],
#   'autoPay': ['false'],
#   'postalCode': ['66020'],
#   'location': ['Easton,KS,USA'],
#   'country': ['US'],
#   'shippingInfo': [{'shippingServiceCost': [{'@currencyId': 'USD',
#       '__value__': '10.0'}],
#     'shippingType': ['Flat'],
#     'shipToLocations': ['Worldwide'],
#     'expeditedShipping': ['false'],
#     'oneDayShippingAvailable': ['false'],
#     'handlingTime': ['3']}],
#   'sellingStatus': [{'currentPrice': [{'@currencyId': 'USD',
#       '__value__': '125.5'}],
#     'convertedCurrentPrice': [{'@currencyId': 'USD', '__value__': '125.5'}],
#     'bidCount': ['10'],
#     'sellingState': ['EndedWithSales']}],
#   'listingInfo': [{'bestOfferEnabled': ['false'],
#     'buyItNowAvailable': ['false'],
#     'startTime': ['2019-03-21T00:30:01.000Z'],
#     'endTime': ['2019-03-28T00:30:01.000Z'],
#     'listingType': ['Auction'],
#     'gift': ['false'],
#     'watchCount': ['8']}],
#   'returnsAccepted': ['false'],
#   'condition': [{'conditionId': ['3000'],
#     'conditionDisplayName': ['Pre-owned']}],
#   'isMultiVariationListing': ['false'],
#   'pictureURLLarge': ['https://i.ebayimg.com/00/s/MTYwMFgxMjAw/z/IYQAAOSw8Ipckh5o/$_1.JPG'],
#   'topRatedListing': ['false']}]

# %%
# For BUY IT NOW:
def find_completed_auction_BIN(PAGE):
    '''Make a request to the eBay API and return the JSON text of this page number'''
    r = requests.get(f'https://svcs.ebay.com/services/search/FindingService/v1?'
                 f'OPERATION-NAME={FIND_COMPLETED}&'
                 f'X-EBAY-SOA-SECURITY-APPNAME={API_KEY}&'
                 f'RESPONSE-DATA-FORMAT=JSON&' # This value can be altered if you're not into JSON responses
                 f'REST-PAYLOAD&'
                 f'GLOBAL-ID={USA}&' # seems to prioritize the value you enter but returns other stuff too
                 f'categoryId={MENS_SUNGLASSES}&' # Product category goes here
                 f'descriptionSearch=true&' # More verbose responses
                 f'{ITEM_FILTER_0}&' # USED
                 f'{ITEM_FILTER_1}&' # NO DUPES
                 f'{ITEM_FILTER_2}&' # MINPRICE
                 f'{ITEM_FILTER_3}&' # NO LOTS
                 f'{ITEM_FILTER_4}&' # ONLY SOLD
                 f'{ITEM_FILTER_7}&' # BUY IT NOW ONLY
                 f'paginationInput.pageNumber={str(PAGE)}&' # value to be looped through when collecting lotsa data
                 f'outputSelector=PictureURLLarge') # Why not grab the thumbnail URLs too. Could be cool
    if r.json()['findCompletedItemsResponse'][0].get('searchResult'):
        return r.json()['findCompletedItemsResponse'][0]['searchResult'][0]['item']
    else:
        return None

# %%
def get_specs(ITEM_ID):
    '''Return the specifics of a single eBay auction. String input.'''
    r2 = requests.get('http://open.api.ebay.com/shopping?'
                    f'callname=GetSingleItem&'
                    f'responseencoding=JSON&'
                    f'appid={API_KEY}&'
                    f'siteid=0&' # USA Store
                    f'version=967&' # What is this?
                    f'ItemID={ITEM_ID}&' # Assigned above
                    f'IncludeSelector=Details,ItemSpecifics,TextDescription')
    try:
        return r2.json()['Item']
    except KeyError:
        pass

# %%
# Seems like there's some variability between items when it comes to item specifics field.
# ### Persisting some Data for Analysis

# Just write first page of listing results to .json files:
def persist_page_to_json(PAGE):
    '''Saves a page of JSON responses to one json per sale / item'''
    for i in range(len(PAGE)):
        with open("data/listings/%s_listing.json" % (PAGE[i]['itemId'][0]), 'w') as f:  # writing JSON object
            json.dump(PAGE[i], f)

# %%
# Now write one page of details to a JSON:
def persist_spec_to_json(spec):
    '''Writes one page of Axe Specs to one json'''
    try:
        with open("data/specs/%s_specs.json" % (spec['ItemID']), 'w') as f:  # writing JSON object
            json.dump(spec, f)
    except TypeError:
        pass
    pass

# %%
# Okay, careful, this is where we start to hammer the eBay API a little bit.
def spam_the_api(start_page, stop_page, fetch_function):
    existing_files = [name.split('_')[0] for name in os.listdir('data/specs/') if not name.startswith('.')] # Ignore .DS_Store
    
    j = 0
    k = 0
    
    '''Spams the eBay API for pages of item DATA'''
    
    for i in range(start_page+1, stop_page+1):
        page = fetch_function(i)
        if page != None:
            persist_page_to_json(page)
            for item in page:
                k += 1
                if item['itemId'][0] not in existing_files:
                    j += 1
                    print(f'Get page {i} item {k}')
                    persist_spec_to_json(get_specs(item['itemId'][0]))
                else:
                    print(f'Skip page {i} item {k}')    
    print(f'\nChecked {k} items')
    print(f'\nGot {j} new items')

# %%
# Again, you only get 5k API calls per day.
spam_the_api(0,3, find_completed_auction)
# Out:
# Get page 2 item 1
# Get page 2 item 2
# Get page 2 item 3
# Get page 2 item 4
# Get page 2 item 5
# Get page 2 item 6
# Get page 2 item 7
# Get page 2 item 8
# Get page 2 item 9
# Get page 2 item 10
# Get page 2 item 11
# Get page 2 item 12
# Get page 2 item 13
# Get page 2 item 14
# Get page 2 item 15
# Get page 2 item 16
# Get page 2 item 17
# Get page 2 item 18
# Get page 2 item 19
# Get page 2 item 20
# Get page 2 item 21
# Get page 2 item 22
# Get page 2 item 23
# Get page 2 item 24
# Get page 2 item 25
# Get page 2 item 26
# Get page 2 item 27
# Get page 2 item 28
# Get page 2 item 29
# Get page 2 item 30
# Get page 2 item 31
# Get page 2 item 32
# Get page 2 item 33
# Get page 2 item 34
# Get page 2 item 35
# Get page 2 item 36
# Get page 2 item 37
# Get page 2 item 38
# Get page 2 item 39
# Get page 2 item 40
# Get page 2 item 41
# Get page 2 item 42
# Get page 2 item 43
# Get page 2 item 44
# Get page 2 item 45
# Get page 2 item 46
# Get page 2 item 47
# Get page 2 item 48
# Get page 2 item 49
# Get page 2 item 50
# Get page 2 item 51
# Get page 2 item 52
# Get page 2 item 53
# Get page 2 item 54
# Get page 2 item 55
# Get page 2 item 56
# Get page 2 item 57
# Get page 2 item 58
# Get page 2 item 59
# Get page 2 item 60
# Get page 2 item 61
# Get page 2 item 62
# Get page 2 item 63
# Get page 2 item 64
# Get page 2 item 65
# Get page 2 item 66
# Get page 2 item 67
# Get page 2 item 68
# Get page 2 item 69
# Get page 2 item 70
