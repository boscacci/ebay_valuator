# %%
import json, os, requests

from key import API_KEY

API_KEY = API_KEY # Enter your API Key/"App ID" Here. Mine was 40 chars long.

# FILM_CAMS = '15230'
# ELEC_GUITARS = '33034' # Category code for electric guitars on eBay.
# WATCHES = '14324'
MENS_SUNGLASSES = '79720'

# %%
USA = 'EBAY-US' # USA Marketplace only. API seems to start returning stuff from other markets eventually anyhow
USED = '3000' # Just the code for item condition "used". This is the focus of this project.
AUCTIONWITHBIN = "AuctionWithBIN"
AUCTION = "Auction"

ITEM_FILTER_0 = f'itemFilter(0).name=Condition&itemFilter(0).value={USED}' # Only used guitars
ITEM_FILTER_1 = f'itemFilter(1).name=HideDuplicateItems&itemFilter(1).value=true' # No duplicate listings
ITEM_FILTER_2 = f'itemFilter(2).name=MinPrice&itemFilter(2).value=49' # Only items that sold for > this value
ITEM_FILTER_3 = f'itemFilter(3).name=MaxQuantity&itemFilter(3).value=1' # No lots or batch sales. One item at a time
ITEM_FILTER_4 = f'itemFilter(4).name=SoldItemsOnly&itemFilter(4).value=true' # Only looking at listings that sold.
ITEM_FILTER_5 = f'itemFilter(5).name=ListingType&itemFilter(5).value={AUCTION}' # Select sale type.
ITEM_FILTER_6 = f'itemFilter(6).name=MaxPrice&itemFilter(6).value=2000' # Only items that sold for < this value
ITEM_FILTER_7 = f'itemFilter(7).name=listingType&itemFilter(7).value={AUCTIONWITHBIN}' # Select sale type.

FIND_COMPLETED = 'findCompletedItems' # This is the eBay API endpoint service we'll be querying.

# %%
def find_completed_auction(PAGE):
    '''Make a request to the eBay API and return the JSON text of this page number'''
    r = requests.get(f'https://svcs.ebay.com/services/search/FindingService/v1?'
                 f'OPERATION-NAME={FIND_COMPLETED}&'
                 f'X-EBAY-SOA-SECURITY-APPNAME={API_KEY}&'
                 f'RESPONSE-DATA-FORMAT=JSON&' # This value can be altered if you're not into JSON responses
                 f'REST-PAYLOAD&'
                 f'GLOBAL-ID={USA}&' # seems to prioritize the value you enter but returns other stuff too
                 f'categoryId={MENS_SUNGLASSES}&' # Product category goes here
                 f'descriptionSearch=true&' # More verbose responses
                 f'{ITEM_FILTER_0}&' # USED
                 f'{ITEM_FILTER_1}&' # NO DUPES
                 f'{ITEM_FILTER_2}&' # MINPRICE
                 f'{ITEM_FILTER_3}&' # NO LOTS
                 f'{ITEM_FILTER_4}&' # ONLY SOLD
                 f'{ITEM_FILTER_5}&' # AUCTIONS ONLY
                 f'{ITEM_FILTER_6}&' # MAX PRICE
                 f'paginationInput.pageNumber={str(PAGE)}&' # value to be looped through when collecting lotsa data
                 f'outputSelector=PictureURLLarge') # Why not grab the thumbnail URLs too. Could be cool
    if r.json()['findCompletedItemsResponse'][0].get('searchResult'):
        return r.json()['findCompletedItemsResponse'][0]['searchResult'][0]['item']
    else:
        return None

# %%
# For BUY IT NOW:
def find_completed_auction_BIN(PAGE):
    '''Make a request to the eBay API and return the JSON text of this page number'''
    r = requests.get(f'https://svcs.ebay.com/services/search/FindingService/v1?'
                 f'OPERATION-NAME={FIND_COMPLETED}&'
                 f'X-EBAY-SOA-SECURITY-APPNAME={API_KEY}&'
                 f'RESPONSE-DATA-FORMAT=JSON&' # This value can be altered if you're not into JSON responses
                 f'REST-PAYLOAD&'
                 f'GLOBAL-ID={USA}&' # seems to prioritize the value you enter but returns other stuff too
                 f'categoryId={MENS_SUNGLASSES}&' # Product category goes here
                 f'descriptionSearch=true&' # More verbose responses
                 f'{ITEM_FILTER_0}&' # USED
                 f'{ITEM_FILTER_1}&' # NO DUPES
                 f'{ITEM_FILTER_2}&' # MINPRICE
                 f'{ITEM_FILTER_3}&' # NO LOTS
                 f'{ITEM_FILTER_4}&' # ONLY SOLD
                 f'{ITEM_FILTER_7}&' # BUY IT NOW ONLY
                 f'paginationInput.pageNumber={str(PAGE)}&' # value to be looped through when collecting lotsa data
                 f'outputSelector=PictureURLLarge') # Why not grab the thumbnail URLs too. Could be cool
    if r.json()['findCompletedItemsResponse'][0].get('searchResult'):
        return r.json()['findCompletedItemsResponse'][0]['searchResult'][0]['item']
    else:
        return None

# %%
def get_specs(ITEM_ID):
    '''Return the specifics of a single eBay auction. String input.'''
    r2 = requests.get('http://open.api.ebay.com/shopping?'
                    f'callname=GetSingleItem&'
                    f'responseencoding=JSON&'
                    f'appid={API_KEY}&'
                    f'siteid=0&' # USA Store
                    f'version=967&' # What is this?
                    f'ItemID={ITEM_ID}&' # Assigned above
                    f'IncludeSelector=Details,ItemSpecifics,TextDescription')
    try:
        return r2.json()['Item']
    except KeyError:
        pass

# %%
# Seems like there's some variability between items when it comes to item specifics field.
# ### Persisting some Data for Analysis

# Just write first page of listing results to .json files:
def persist_page_to_json(PAGE):
    '''Saves a page of JSON responses to one json per sale / item'''
    for i in range(len(PAGE)):
        with open("data/listings/%s_listing.json" % (PAGE[i]['itemId'][0]), 'w') as f:  # writing JSON object
            json.dump(PAGE[i], f)

# %%
# Now write one page of details to a JSON:
def persist_spec_to_json(spec):
    '''Writes one page of Axe Specs to one json'''
    try:
        with open("data/specs/%s_specs.json" % (spec['ItemID']), 'w') as f:  # writing JSON object
            json.dump(spec, f)
    except TypeError:
        pass
    pass

# %%
# Okay, careful, this is where we start to hammer the eBay API a little bit.
def spam_the_api(start_page, stop_page, fetch_function):
    existing_files = [name.split('_')[0] for name in os.listdir('data/specs/') if not name.startswith('.')] # Ignore .DS_Store
    
    j = 0
    k = 0
    
    '''Spams the eBay API for pages of item DATA'''
    
    for i in range(start_page+1, stop_page+1):
        page = fetch_function(i)
        if page != None:
            persist_page_to_json(page)
            for item in page:
                k += 1
                if item['itemId'][0] not in existing_files:
                    j += 1
                    print(f'Get page {i} item {k}')
                    persist_spec_to_json(get_specs(item['itemId'][0]))
                else:
                    print(f'Skip page {i} item {k}')    
    print(f'\nChecked {k} items')
    print(f'\nGot {j} new items')

# %%
# Again, you only get 5k API calls per day.
spam_the_api(0,20, find_completed_auction)
# Out:
# Skip page 1 item 1
# Skip page 1 item 2
# Skip page 1 item 3
# Skip page 1 item 4
# Skip page 1 item 5
# Skip page 1 item 6
# Skip page 1 item 7
# Skip page 1 item 8
# Skip page 1 item 9
# Skip page 1 item 10
# Skip page 1 item 11
# Skip page 1 item 12
# Skip page 1 item 13
# Skip page 1 item 14
# Skip page 1 item 15
# Skip page 1 item 16
# Skip page 1 item 17
# Skip page 1 item 18
# Skip page 1 item 19
# Skip page 1 item 20
# Skip page 1 item 21
# Skip page 1 item 22
# Skip page 1 item 23
# Skip page 1 item 24
# Skip page 1 item 25
# Skip page 1 item 26
# Skip page 1 item 27
# Skip page 1 item 28
# Skip page 1 item 29
# Skip page 1 item 30
# Get page 1 item 31
# Get page 1 item 32
# Skip page 1 item 33
# Skip page 1 item 34
# Skip page 1 item 35
# Skip page 1 item 36
# Skip page 1 item 37
# Skip page 1 item 38
# Skip page 1 item 39
# Skip page 1 item 40
# Skip page 1 item 41
# Skip page 1 item 42
# Skip page 1 item 43
# Skip page 1 item 44
# Skip page 1 item 45
# Skip page 1 item 46
# Skip page 1 item 47
# Skip page 1 item 48
# Skip page 1 item 49
# Skip page 1 item 50
# Skip page 1 item 51
# Skip page 1 item 52
# Skip page 1 item 53
# Skip page 1 item 54
# Skip page 1 item 55
# Skip page 1 item 56
# Skip page 1 item 57
# Skip page 1 item 58
# Skip page 1 item 59
# Skip page 1 item 60
# Skip page 1 item 61
# Skip page 1 item 62
# Skip page 1 item 63
# Skip page 1 item 64
# Skip page 1 item 65
# Skip page 1 item 66
# Skip page 1 item 67
# Skip page 1 item 68
# Skip page 1 item 69
# Skip page 1 item 70
# Skip page 1 item 71
# Skip page 1 item 72
# Skip page 1 item 73
# Skip page 1 item 74
# Skip page 1 item 75
# Skip page 1 item 76
# Skip page 1 item 77
# Skip page 1 item 78
# Skip page 1 item 79
# Skip page 1 item 80
# Skip page 1 item 81
# Skip page 1 item 82
# Skip page 1 item 83
# Skip page 1 item 84
# Skip page 1 item 85
# Get page 1 item 86
# Get page 1 item 87
# Get page 1 item 88
# Get page 1 item 89
# Skip page 1 item 90
# Skip page 1 item 91
# Skip page 1 item 92
# Skip page 1 item 93
# Skip page 1 item 94
# Skip page 1 item 95
# Skip page 1 item 96
# Skip page 1 item 97
# Skip page 1 item 98
# Skip page 1 item 99
# Skip page 1 item 100
# Skip page 2 item 101
# Skip page 2 item 102
# Skip page 2 item 103
# Skip page 2 item 104
# Skip page 2 item 105
# Skip page 2 item 106
# Skip page 2 item 107
# Skip page 2 item 108
# Skip page 2 item 109
# Skip page 2 item 110
# Skip page 2 item 111
# Skip page 2 item 112
# Skip page 2 item 113
# Skip page 2 item 114
# Skip page 2 item 115
# Skip page 2 item 116
# Skip page 2 item 117
# Skip page 2 item 118
# Skip page 2 item 119
# Skip page 2 item 120
# Skip page 2 item 121
# Skip page 2 item 122
# Skip page 2 item 123
# Skip page 2 item 124
# Skip page 2 item 125
# Skip page 2 item 126
# Skip page 2 item 127
# Skip page 2 item 128
# Skip page 2 item 129
# Skip page 2 item 130
# Skip page 2 item 131
# Skip page 2 item 132
# Skip page 2 item 133
# Skip page 2 item 134
# Skip page 2 item 135
# Skip page 2 item 136
# Skip page 2 item 137
# Skip page 2 item 138
# Skip page 2 item 139
# Skip page 2 item 140
# Skip page 2 item 141
# Skip page 2 item 142
# Skip page 2 item 143
# Skip page 2 item 144
# Skip page 2 item 145
# Skip page 2 item 146
# Skip page 2 item 147
# Skip page 2 item 148
# Skip page 2 item 149
# Skip page 2 item 150
# Skip page 2 item 151
# Skip page 2 item 152
# Skip page 2 item 153
# Skip page 2 item 154
# Skip page 2 item 155
# Skip page 2 item 156
# Skip page 2 item 157
# Skip page 2 item 158
# Skip page 2 item 159
# Skip page 2 item 160
# Skip page 2 item 161
# Skip page 2 item 162
# Skip page 2 item 163
# Skip page 2 item 164
# Skip page 2 item 165
# Skip page 2 item 166
# Skip page 2 item 167
# Skip page 2 item 168
# Skip page 2 item 169
# Skip page 2 item 170
# Skip page 2 item 171
# Skip page 2 item 172
# Skip page 2 item 173
# Skip page 2 item 174
# Skip page 2 item 175
# Skip page 2 item 176
# Skip page 2 item 177
# Skip page 2 item 178
# Skip page 2 item 179
# Skip page 2 item 180
# Skip page 2 item 181
# Skip page 2 item 182
# Skip page 2 item 183
# Skip page 2 item 184
# Skip page 2 item 185
# Skip page 2 item 186
# Skip page 2 item 187
# Skip page 2 item 188
# Skip page 2 item 189
# Skip page 2 item 190
# Skip page 2 item 191
# Skip page 2 item 192
# Skip page 2 item 193
# Skip page 2 item 194
# Skip page 2 item 195
# Skip page 2 item 196
# Skip page 2 item 197
# Skip page 2 item 198
# Skip page 2 item 199
# Skip page 2 item 200
# Skip page 3 item 201
# Skip page 3 item 202
# Skip page 3 item 203
# Skip page 3 item 204
# Skip page 3 item 205
# Skip page 3 item 206
# Skip page 3 item 207
# Skip page 3 item 208
# Skip page 3 item 209
# Skip page 3 item 210
# Skip page 3 item 211
# Skip page 3 item 212
# Skip page 3 item 213
# Skip page 3 item 214
# Skip page 3 item 215
# Skip page 3 item 216
# Skip page 3 item 217
# Skip page 3 item 218
# Skip page 3 item 219
# Skip page 3 item 220
# Skip page 3 item 221
# Skip page 3 item 222
# Skip page 3 item 223
# Skip page 3 item 224
# Skip page 3 item 225
# Skip page 3 item 226
# Skip page 3 item 227
# Skip page 3 item 228
# Skip page 3 item 229
# Skip page 3 item 230
# Skip page 3 item 231
# Skip page 3 item 232
# Skip page 3 item 233
# Skip page 3 item 234
# Skip page 3 item 235
# Skip page 3 item 236
# Skip page 3 item 237
# Skip page 3 item 238
# Skip page 3 item 239
# Skip page 3 item 240
# Skip page 3 item 241
# Skip page 3 item 242
# Skip page 3 item 243
# Skip page 3 item 244
# Skip page 3 item 245
# Skip page 3 item 246
# Skip page 3 item 247
# Skip page 3 item 248
# Skip page 3 item 249
# Skip page 3 item 250
# Skip page 3 item 251
# Skip page 3 item 252
# Skip page 3 item 253
# Skip page 3 item 254
# Skip page 3 item 255
# Skip page 3 item 256
# Skip page 3 item 257
# Skip page 3 item 258
# Skip page 3 item 259
# Skip page 3 item 260
# Skip page 3 item 261
# Skip page 3 item 262
# Skip page 3 item 263
# Skip page 3 item 264
# Skip page 3 item 265
# Skip page 3 item 266
# Skip page 3 item 267
# Skip page 3 item 268
# Skip page 3 item 269
# Skip page 3 item 270
# Skip page 3 item 271
# Skip page 3 item 272
# Skip page 3 item 273
# Skip page 3 item 274
# Skip page 3 item 275
# Skip page 3 item 276
# Skip page 3 item 277
# Skip page 3 item 278
# Skip page 3 item 279
# Skip page 3 item 280
# Skip page 3 item 281
# Skip page 3 item 282
# Skip page 3 item 283
# Skip page 3 item 284
# Skip page 3 item 285
# Skip page 3 item 286
# Skip page 3 item 287
# Skip page 3 item 288
# Skip page 3 item 289
# Skip page 3 item 290
# Skip page 3 item 291
# Skip page 3 item 292
# Skip page 3 item 293
# Skip page 3 item 294
# Skip page 3 item 295
# Skip page 3 item 296
# Skip page 3 item 297
# Skip page 3 item 298
# Skip page 3 item 299
# Skip page 3 item 300
# Skip page 4 item 301
# Skip page 4 item 302
# Skip page 4 item 303
# Skip page 4 item 304
# Skip page 4 item 305
# Skip page 4 item 306
# Skip page 4 item 307
# Skip page 4 item 308
# Skip page 4 item 309
# Skip page 4 item 310
# Skip page 4 item 311
# Skip page 4 item 312
# Skip page 4 item 313
# Skip page 4 item 314
# Skip page 4 item 315
# Skip page 4 item 316
# Skip page 4 item 317
# Skip page 4 item 318
# Skip page 4 item 319
# Skip page 4 item 320
# Skip page 4 item 321
# Skip page 4 item 322
# Skip page 4 item 323
# Skip page 4 item 324
# Skip page 4 item 325
# Skip page 4 item 326
# Skip page 4 item 327
# Skip page 4 item 328
# Skip page 4 item 329
# Skip page 4 item 330
# Skip page 4 item 331
# Skip page 4 item 332
# Skip page 4 item 333
# Skip page 4 item 334
# Skip page 4 item 335
# Skip page 4 item 336
# Skip page 4 item 337
# Skip page 4 item 338
# Skip page 4 item 339
# Skip page 4 item 340
# Skip page 4 item 341
# Skip page 4 item 342
# Skip page 4 item 343
# Skip page 4 item 344
# Skip page 4 item 345
# Skip page 4 item 346
# Skip page 4 item 347
# Skip page 4 item 348
# Skip page 4 item 349
# Skip page 4 item 350
# Skip page 4 item 351
# Skip page 4 item 352
# Skip page 4 item 353
# Skip page 4 item 354
# Skip page 4 item 355
# Skip page 4 item 356
# Skip page 4 item 357
# Skip page 4 item 358
# Skip page 4 item 359
# Skip page 4 item 360
# Skip page 4 item 361
# Skip page 4 item 362
# Skip page 4 item 363
# Skip page 4 item 364
# Skip page 4 item 365
# Skip page 4 item 366
# Skip page 4 item 367
# Skip page 4 item 368
# Skip page 4 item 369
# Skip page 4 item 370
# Skip page 4 item 371
# Skip page 4 item 372
# Skip page 4 item 373
# Skip page 4 item 374
# Skip page 4 item 375
# Skip page 4 item 376
# Skip page 4 item 377
# Skip page 4 item 378
# Skip page 4 item 379
# Skip page 4 item 380
# Skip page 4 item 381
# Skip page 4 item 382
# Skip page 4 item 383
# Skip page 4 item 384
# Skip page 4 item 385
# Skip page 4 item 386
# Skip page 4 item 387
# Skip page 4 item 388
# Skip page 4 item 389
# Skip page 4 item 390
# Skip page 4 item 391
# Skip page 4 item 392
# Skip page 4 item 393
# Skip page 4 item 394
# Skip page 4 item 395
# Skip page 4 item 396
# Skip page 4 item 397
# Skip page 4 item 398
# Skip page 4 item 399
# Skip page 4 item 400
# Skip page 5 item 401
# Skip page 5 item 402
# Skip page 5 item 403
# Skip page 5 item 404
# Skip page 5 item 405
# Skip page 5 item 406
# Skip page 5 item 407
# Skip page 5 item 408
# Skip page 5 item 409
# Skip page 5 item 410
# Skip page 5 item 411
# Skip page 5 item 412
# Skip page 5 item 413
# Skip page 5 item 414
# Skip page 5 item 415
# Skip page 5 item 416
# Skip page 5 item 417
# Skip page 5 item 418
# Skip page 5 item 419
# Skip page 5 item 420
# Skip page 5 item 421
# Skip page 5 item 422
# Skip page 5 item 423
# Skip page 5 item 424
# Skip page 5 item 425
# Skip page 5 item 426
# Skip page 5 item 427
# Skip page 5 item 428
# Skip page 5 item 429
# Skip page 5 item 430
# Skip page 5 item 431
# Skip page 5 item 432
# Skip page 5 item 433
# Skip page 5 item 434
# Skip page 5 item 435
# Skip page 5 item 436
# Skip page 5 item 437
# Skip page 5 item 438
# Skip page 5 item 439
# Skip page 5 item 440
# Skip page 5 item 441
# Skip page 5 item 442
# Skip page 5 item 443
# Skip page 5 item 444
# Skip page 5 item 445
# Skip page 5 item 446
# Skip page 5 item 447
# Skip page 5 item 448
# Skip page 5 item 449
# Skip page 5 item 450
# Skip page 5 item 451
# Skip page 5 item 452
# Skip page 5 item 453
# Skip page 5 item 454
# Skip page 5 item 455
# Skip page 5 item 456
# Skip page 5 item 457
# Skip page 5 item 458
# Skip page 5 item 459
# Skip page 5 item 460
# Skip page 5 item 461
# Skip page 5 item 462
# Skip page 5 item 463
# Skip page 5 item 464
# Skip page 5 item 465
# Skip page 5 item 466
# Skip page 5 item 467
# Skip page 5 item 468
# Skip page 5 item 469
# Skip page 5 item 470
# Skip page 5 item 471
# Skip page 5 item 472
# Skip page 5 item 473
# Skip page 5 item 474
# Skip page 5 item 475
# Skip page 5 item 476
# Skip page 5 item 477
# Skip page 5 item 478
# Skip page 5 item 479
# Skip page 5 item 480
# Skip page 5 item 481
# Skip page 5 item 482
# Skip page 5 item 483
# Skip page 5 item 484
# Skip page 5 item 485
# Skip page 5 item 486
# Skip page 5 item 487
# Skip page 5 item 488
# Skip page 5 item 489
# Skip page 5 item 490
# Skip page 5 item 491
# Skip page 5 item 492
# Skip page 5 item 493
# Skip page 5 item 494
# Skip page 5 item 495
# Skip page 5 item 496
# Skip page 5 item 497
# Skip page 5 item 498
# Skip page 5 item 499
# Skip page 5 item 500
# Skip page 6 item 501
# Skip page 6 item 502
# Skip page 6 item 503
# Skip page 6 item 504
# Skip page 6 item 505
# Skip page 6 item 506
# Skip page 6 item 507
# Skip page 6 item 508
# Skip page 6 item 509
# Skip page 6 item 510
# Skip page 6 item 511
# Skip page 6 item 512
# Skip page 6 item 513
# Skip page 6 item 514
# Skip page 6 item 515
# Skip page 6 item 516
# Skip page 6 item 517
# Skip page 6 item 518
# Skip page 6 item 519
# Skip page 6 item 520
# Skip page 6 item 521
# Skip page 6 item 522
# Skip page 6 item 523
# Skip page 6 item 524
# Skip page 6 item 525
# Skip page 6 item 526
# Skip page 6 item 527
# Skip page 6 item 528
# Skip page 6 item 529
# Skip page 6 item 530
# Skip page 6 item 531
# Skip page 6 item 532
# Skip page 6 item 533
# Skip page 6 item 534
# Skip page 6 item 535
# Skip page 6 item 536
# Skip page 6 item 537
# Skip page 6 item 538
# Skip page 6 item 539
# Skip page 6 item 540
# Skip page 6 item 541
# Skip page 6 item 542
# Skip page 6 item 543
# Skip page 6 item 544
# Skip page 6 item 545
# Skip page 6 item 546
# Skip page 6 item 547
# Skip page 6 item 548
# Skip page 6 item 549
# Skip page 6 item 550
# Skip page 6 item 551
# Skip page 6 item 552
# Skip page 6 item 553
# Skip page 6 item 554
# Skip page 6 item 555
# Skip page 6 item 556
# Skip page 6 item 557
# Skip page 6 item 558
# Skip page 6 item 559
# Skip page 6 item 560
# Skip page 6 item 561
# Skip page 6 item 562
# Skip page 6 item 563
# Skip page 6 item 564
# Skip page 6 item 565
# Skip page 6 item 566
# Skip page 6 item 567
# Skip page 6 item 568
# Skip page 6 item 569
# Skip page 6 item 570
# Skip page 6 item 571
# Skip page 6 item 572
# Skip page 6 item 573
# Skip page 6 item 574
# Skip page 6 item 575
# Skip page 6 item 576
# Skip page 6 item 577
# Skip page 6 item 578
# Skip page 6 item 579
# Skip page 6 item 580
# Skip page 6 item 581
# Skip page 6 item 582
# Skip page 6 item 583
# Skip page 6 item 584
# Skip page 6 item 585
# Skip page 6 item 586
# Skip page 6 item 587
# Skip page 6 item 588
# Skip page 6 item 589
# Skip page 6 item 590
# Skip page 6 item 591
# Skip page 6 item 592
# Skip page 6 item 593
# Skip page 6 item 594
# Skip page 6 item 595
# Skip page 6 item 596
# Skip page 6 item 597
# Skip page 6 item 598
# Skip page 6 item 599
# Skip page 6 item 600
# Skip page 7 item 601
# Skip page 7 item 602
# Skip page 7 item 603
# Skip page 7 item 604
# Skip page 7 item 605
# Skip page 7 item 606
# Skip page 7 item 607
# Skip page 7 item 608
# Skip page 7 item 609
# Skip page 7 item 610
# Skip page 7 item 611
# Skip page 7 item 612
# Skip page 7 item 613
# Skip page 7 item 614
# Skip page 7 item 615
# Skip page 7 item 616
# Skip page 7 item 617
# Skip page 7 item 618
# Skip page 7 item 619
# Skip page 7 item 620
# Skip page 7 item 621
# Skip page 7 item 622
# Skip page 7 item 623
# Skip page 7 item 624
# Skip page 7 item 625
# Skip page 7 item 626
# Skip page 7 item 627
# Skip page 7 item 628
# Skip page 7 item 629
# Skip page 7 item 630
# Skip page 7 item 631
# Skip page 7 item 632
# Skip page 7 item 633
# Skip page 7 item 634
# Skip page 7 item 635
# Skip page 7 item 636
# Skip page 7 item 637
# Skip page 7 item 638
# Skip page 7 item 639
# Skip page 7 item 640
# Skip page 7 item 641
# Skip page 7 item 642
# Skip page 7 item 643
# Skip page 7 item 644
# Skip page 7 item 645
# Skip page 7 item 646
# Skip page 7 item 647
# Skip page 7 item 648
# Skip page 7 item 649
# Skip page 7 item 650
# Skip page 7 item 651
# Skip page 7 item 652
# Skip page 7 item 653
# Skip page 7 item 654
# Skip page 7 item 655
# Skip page 7 item 656
# Skip page 7 item 657
# Skip page 7 item 658
# Skip page 7 item 659
# Skip page 7 item 660
# Skip page 7 item 661
# Skip page 7 item 662
# Skip page 7 item 663
# Skip page 7 item 664
# Skip page 7 item 665
# Skip page 7 item 666
# Skip page 7 item 667
# Skip page 7 item 668
# Skip page 7 item 669
# Skip page 7 item 670
# Skip page 7 item 671
# Skip page 7 item 672
# Skip page 7 item 673
# Skip page 7 item 674
# Skip page 7 item 675
# Skip page 7 item 676
# Skip page 7 item 677
# Skip page 7 item 678
# Skip page 7 item 679
# Get page 7 item 680
# Get page 7 item 681
# Get page 7 item 682
# Get page 7 item 683
# Get page 7 item 684
# Get page 7 item 685
# Get page 7 item 686
# Get page 7 item 687
# Get page 7 item 688
# Get page 7 item 689
# Get page 7 item 690
# Get page 7 item 691
# Get page 7 item 692
# Get page 7 item 693
# Get page 7 item 694
# Get page 7 item 695
# Get page 7 item 696
# Get page 7 item 697
# Get page 7 item 698
# Get page 7 item 699
# Get page 7 item 700
# Get page 8 item 701
# Get page 8 item 702
# Skip page 8 item 703
# Skip page 8 item 704
# Skip page 8 item 705
# Skip page 8 item 706
# Skip page 8 item 707
# Skip page 8 item 708
# Skip page 8 item 709
# Skip page 8 item 710
# Skip page 8 item 711
# Skip page 8 item 712
# Skip page 8 item 713
# Skip page 8 item 714
# Skip page 8 item 715
# Skip page 8 item 716
# Skip page 8 item 717
# Skip page 8 item 718
# Skip page 8 item 719
# Skip page 8 item 720
# Skip page 8 item 721
# Skip page 8 item 722
# Skip page 8 item 723
# Skip page 8 item 724
# Skip page 8 item 725
# Skip page 8 item 726
# Skip page 8 item 727
# Skip page 8 item 728
# Skip page 8 item 729
# Skip page 8 item 730
# Skip page 8 item 731
# Skip page 8 item 732
# Skip page 8 item 733
# Skip page 8 item 734
# Skip page 8 item 735
# Skip page 8 item 736
# Skip page 8 item 737
# Skip page 8 item 738
# Skip page 8 item 739
# Skip page 8 item 740
# Skip page 8 item 741
# Skip page 8 item 742
# Skip page 8 item 743
# Skip page 8 item 744
# Skip page 8 item 745
# Skip page 8 item 746
# Skip page 8 item 747
# Skip page 8 item 748
# Skip page 8 item 749
# Skip page 8 item 750
# Skip page 8 item 751
# Skip page 8 item 752
# Skip page 8 item 753
# Skip page 8 item 754
# Skip page 8 item 755
# Skip page 8 item 756
# Skip page 8 item 757
# Skip page 8 item 758
# Skip page 8 item 759
# Skip page 8 item 760
# Skip page 8 item 761
# Skip page 8 item 762
# Skip page 8 item 763
# Skip page 8 item 764
# Skip page 8 item 765
# Skip page 8 item 766
# Skip page 8 item 767
# Skip page 8 item 768
# Skip page 8 item 769
# Skip page 8 item 770
# Skip page 8 item 771
# Skip page 8 item 772
# Skip page 8 item 773
# Skip page 8 item 774
# Skip page 8 item 775
# Skip page 8 item 776
# Skip page 8 item 777
# Skip page 8 item 778
# Skip page 8 item 779
# Skip page 8 item 780
# Skip page 8 item 781
# Skip page 8 item 782
# Skip page 8 item 783
# Skip page 8 item 784
# Skip page 8 item 785
# Skip page 8 item 786
# Skip page 8 item 787
# Skip page 8 item 788
# Skip page 8 item 789
# Skip page 8 item 790
# Skip page 8 item 791
# Skip page 8 item 792
# Skip page 8 item 793
# Skip page 8 item 794
# Skip page 8 item 795
# Skip page 8 item 796
# Skip page 8 item 797
# Skip page 8 item 798
# Skip page 8 item 799
# Skip page 8 item 800
# Skip page 9 item 801
# Skip page 9 item 802
# Skip page 9 item 803
# Skip page 9 item 804
# Skip page 9 item 805
# Skip page 9 item 806
# Skip page 9 item 807
# Skip page 9 item 808
# Skip page 9 item 809
# Skip page 9 item 810
# Skip page 9 item 811
# Skip page 9 item 812
# Skip page 9 item 813
# Skip page 9 item 814
# Skip page 9 item 815
# Skip page 9 item 816
# Skip page 9 item 817
# Skip page 9 item 818
# Skip page 9 item 819
# Skip page 9 item 820
# Skip page 9 item 821
# Skip page 9 item 822
# Skip page 9 item 823
# Skip page 9 item 824
# Skip page 9 item 825
# Skip page 9 item 826
# Skip page 9 item 827
# Skip page 9 item 828
# Skip page 9 item 829
# Skip page 9 item 830
# Skip page 9 item 831
# Skip page 9 item 832
# Skip page 9 item 833
# Skip page 9 item 834
# Skip page 9 item 835
# Skip page 9 item 836
# Skip page 9 item 837
# Skip page 9 item 838
# Skip page 9 item 839
# Skip page 9 item 840
# Skip page 9 item 841
# Skip page 9 item 842
# Skip page 9 item 843
# Skip page 9 item 844
# Skip page 9 item 845
# Skip page 9 item 846
# Skip page 9 item 847
# Skip page 9 item 848
# Skip page 9 item 849
# Skip page 9 item 850
# Skip page 9 item 851
# Skip page 9 item 852
# Skip page 9 item 853
# Skip page 9 item 854
# Skip page 9 item 855
# Skip page 9 item 856
# Skip page 9 item 857
# Skip page 9 item 858
# Skip page 9 item 859
# Skip page 9 item 860
# Skip page 9 item 861
# Skip page 9 item 862
# Skip page 9 item 863
# Skip page 9 item 864
# Skip page 9 item 865
# Skip page 9 item 866
# Skip page 9 item 867
# Skip page 9 item 868
# Skip page 9 item 869
# Skip page 9 item 870
# Skip page 9 item 871
# Skip page 9 item 872
# Skip page 9 item 873
# Skip page 9 item 874
# Skip page 9 item 875
# Skip page 9 item 876
# Skip page 9 item 877
# Skip page 9 item 878
# Skip page 9 item 879
# Skip page 9 item 880
# Skip page 9 item 881
# Skip page 9 item 882
# Skip page 9 item 883
# Skip page 9 item 884
# Skip page 9 item 885
# Skip page 9 item 886
# Skip page 9 item 887
# Skip page 9 item 888
# Skip page 9 item 889
# Skip page 9 item 890
# Skip page 9 item 891
# Skip page 9 item 892
# Skip page 9 item 893
# Skip page 9 item 894
# Skip page 9 item 895
# Skip page 9 item 896
# Skip page 9 item 897
# Skip page 9 item 898
# Skip page 9 item 899
# Skip page 9 item 900
# Skip page 10 item 901
# Skip page 10 item 902
# Skip page 10 item 903
# Skip page 10 item 904
# Skip page 10 item 905
# Skip page 10 item 906
# Skip page 10 item 907
# Skip page 10 item 908
# Skip page 10 item 909
# Skip page 10 item 910
# Skip page 10 item 911
# Skip page 10 item 912
# Skip page 10 item 913
# Skip page 10 item 914
# Skip page 10 item 915
# Skip page 10 item 916
# Skip page 10 item 917
# Skip page 10 item 918
# Skip page 10 item 919
# Skip page 10 item 920
# Skip page 10 item 921
# Skip page 10 item 922
# Skip page 10 item 923
# Skip page 10 item 924
# Skip page 10 item 925
# Skip page 10 item 926
# Skip page 10 item 927
# Skip page 10 item 928
# Skip page 10 item 929
# Skip page 10 item 930
# Skip page 10 item 931
# Skip page 10 item 932
# Skip page 10 item 933
# Skip page 10 item 934
# Skip page 10 item 935
# Skip page 10 item 936
# Skip page 10 item 937
# Skip page 10 item 938
# Skip page 10 item 939
# Skip page 10 item 940
# Skip page 10 item 941
# Skip page 10 item 942
# Skip page 10 item 943
# Skip page 10 item 944
# Skip page 10 item 945
# Skip page 10 item 946
# Skip page 10 item 947
# Skip page 10 item 948
# Skip page 10 item 949
# Skip page 10 item 950
# Skip page 10 item 951
# Skip page 10 item 952
# Skip page 10 item 953
# Skip page 10 item 954
# Skip page 10 item 955
# Skip page 10 item 956
# Skip page 10 item 957
# Skip page 10 item 958
# Skip page 10 item 959
# Skip page 10 item 960
# Skip page 10 item 961
# Skip page 10 item 962
# Skip page 10 item 963
# Skip page 10 item 964
# Skip page 10 item 965
# Skip page 10 item 966
# Skip page 10 item 967
# Skip page 10 item 968
# Skip page 10 item 969
# Skip page 10 item 970
# Skip page 10 item 971
# Skip page 10 item 972
# Skip page 10 item 973
# Skip page 10 item 974
# Skip page 10 item 975
# Skip page 10 item 976
# Skip page 10 item 977
# Skip page 10 item 978
# Skip page 10 item 979
# Skip page 10 item 980
# Skip page 10 item 981
# Skip page 10 item 982
# Skip page 10 item 983
# Skip page 10 item 984
# Skip page 10 item 985
# Skip page 10 item 986
# Skip page 10 item 987
# Skip page 10 item 988
# Skip page 10 item 989
# Skip page 10 item 990
# Skip page 10 item 991
# Skip page 10 item 992
# Skip page 10 item 993
# Skip page 10 item 994
# Skip page 10 item 995
# Skip page 10 item 996
# Skip page 10 item 997
# Skip page 10 item 998
# Skip page 10 item 999
# Skip page 10 item 1000
# Skip page 11 item 1001
# Skip page 11 item 1002
# Skip page 11 item 1003
# Skip page 11 item 1004
# Skip page 11 item 1005
# Skip page 11 item 1006
# Skip page 11 item 1007
# Skip page 11 item 1008
# Skip page 11 item 1009
# Skip page 11 item 1010
# Skip page 11 item 1011
# Skip page 11 item 1012
# Skip page 11 item 1013
# Skip page 11 item 1014
# Skip page 11 item 1015
# Skip page 11 item 1016
# Skip page 11 item 1017
# Skip page 11 item 1018
# Skip page 11 item 1019
# Skip page 11 item 1020
# Skip page 11 item 1021
# Skip page 11 item 1022
# Skip page 11 item 1023
# Skip page 11 item 1024
# Skip page 11 item 1025
# Skip page 11 item 1026
# Skip page 11 item 1027
# Skip page 11 item 1028
# Skip page 11 item 1029
# Skip page 11 item 1030
# Skip page 11 item 1031
# Skip page 11 item 1032
# Skip page 11 item 1033
# Skip page 11 item 1034
# Skip page 11 item 1035
# Skip page 11 item 1036
# Skip page 11 item 1037
# Skip page 11 item 1038
# Skip page 11 item 1039
# Skip page 11 item 1040
# Skip page 11 item 1041
# Skip page 11 item 1042
# Skip page 11 item 1043
# Skip page 11 item 1044
# Skip page 11 item 1045
# Skip page 11 item 1046
# Skip page 11 item 1047
# Skip page 11 item 1048
# Skip page 11 item 1049
# Skip page 11 item 1050
# Skip page 11 item 1051
# Skip page 11 item 1052
# Skip page 11 item 1053
# Skip page 11 item 1054
# Skip page 11 item 1055
# Skip page 11 item 1056
# Skip page 11 item 1057
# Skip page 11 item 1058
# Skip page 11 item 1059
# Skip page 11 item 1060
# Skip page 11 item 1061
# Skip page 11 item 1062
# Skip page 11 item 1063
# Skip page 11 item 1064
# Skip page 11 item 1065
# Skip page 11 item 1066
# Skip page 11 item 1067
# Skip page 11 item 1068
# Skip page 11 item 1069
# Skip page 11 item 1070
# Skip page 11 item 1071
# Skip page 11 item 1072
# Skip page 11 item 1073
# Skip page 11 item 1074
# Skip page 11 item 1075
# Skip page 11 item 1076
# Skip page 11 item 1077
# Skip page 11 item 1078
# Skip page 11 item 1079
# Skip page 11 item 1080
# Skip page 11 item 1081
# Skip page 11 item 1082
# Skip page 11 item 1083
# Skip page 11 item 1084
# Skip page 11 item 1085
# Skip page 11 item 1086
# Skip page 11 item 1087
# Skip page 11 item 1088
# Skip page 11 item 1089
# Skip page 11 item 1090
# Skip page 11 item 1091
# Skip page 11 item 1092
# Skip page 11 item 1093
# Skip page 11 item 1094
# Skip page 11 item 1095
# Skip page 11 item 1096
# Skip page 11 item 1097
# Skip page 11 item 1098
# Skip page 11 item 1099
# Skip page 11 item 1100
# Skip page 12 item 1101
# Skip page 12 item 1102
# Skip page 12 item 1103
# Skip page 12 item 1104
# Skip page 12 item 1105
# Skip page 12 item 1106
# Skip page 12 item 1107
# Skip page 12 item 1108
# Skip page 12 item 1109
# Skip page 12 item 1110
# Skip page 12 item 1111
# Skip page 12 item 1112
# Skip page 12 item 1113
# Skip page 12 item 1114
# Skip page 12 item 1115
# Skip page 12 item 1116
# Skip page 12 item 1117
# Skip page 12 item 1118
# Skip page 12 item 1119
# Skip page 12 item 1120
# Skip page 12 item 1121
# Skip page 12 item 1122
# Skip page 12 item 1123
# Skip page 12 item 1124
# Skip page 12 item 1125
# Skip page 12 item 1126
# Skip page 12 item 1127
# Skip page 12 item 1128
# Skip page 12 item 1129
# Skip page 12 item 1130
# Skip page 12 item 1131
# Skip page 12 item 1132
# Skip page 12 item 1133
# Skip page 12 item 1134
# Skip page 12 item 1135
# Skip page 12 item 1136
# Skip page 12 item 1137
# Skip page 12 item 1138
# Skip page 12 item 1139
# Skip page 12 item 1140
# Skip page 12 item 1141
# Skip page 12 item 1142
# Skip page 12 item 1143
# Skip page 12 item 1144
# Skip page 12 item 1145
# Skip page 12 item 1146
# Skip page 12 item 1147
# Skip page 12 item 1148
# Skip page 12 item 1149
# Skip page 12 item 1150
# Skip page 12 item 1151
# Skip page 12 item 1152
# Skip page 12 item 1153
# Skip page 12 item 1154
# Skip page 12 item 1155
# Skip page 12 item 1156
# Skip page 12 item 1157
# Skip page 12 item 1158
# Skip page 12 item 1159
# Skip page 12 item 1160
# Skip page 12 item 1161
# Skip page 12 item 1162
# Skip page 12 item 1163
# Skip page 12 item 1164
# Skip page 12 item 1165
# Skip page 12 item 1166
# Skip page 12 item 1167
# Skip page 12 item 1168
# Skip page 12 item 1169
# Skip page 12 item 1170
# Skip page 12 item 1171
# Skip page 12 item 1172
# Skip page 12 item 1173
# Skip page 12 item 1174
# Skip page 12 item 1175
# Skip page 12 item 1176
# Skip page 12 item 1177
# Skip page 12 item 1178
# Skip page 12 item 1179
# Get page 12 item 1180
# Get page 12 item 1181
# Get page 12 item 1182
# Get page 12 item 1183
# Get page 12 item 1184
# Get page 12 item 1185
# Get page 12 item 1186
# Get page 12 item 1187
# Get page 12 item 1188

# %%
spam_the_api(0, 20, find_completed_auction_BIN)
